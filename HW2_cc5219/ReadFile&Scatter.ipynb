# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import csv
import os
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dfdata=os.getenv("DFDATA")
dfdata
# Out:
# '/gws/open/NYCOpenData/nycopendata/data'

# %%
os.chdir(os.getenv("DFDATA"))

# %%
os.chdir('zkky-n5j3')

# %%
os.chdir('1414246141')

# %%
ls
# Out:
# zkky-n5j3

# %%
data = pd.read_csv("zkky-n5j3")
data.head()
# Out:
#    Neversink Date                Neversink Elevation  Neversink Storage  \
# 0  03/01/2005 04:00:00 PM +0000              1440.21              35570
# 1  03/02/2005 04:00:00 PM +0000              1440.22              35575
# 2  03/03/2005 04:00:00 PM +0000              1440.21              35570
# 3  03/04/2005 04:00:00 PM +0000              1440.21              35570
# 4  03/05/2005 04:00:00 PM +0000              1440.21              35570
#
#       Rondout Date               Rondout Elevation  Rondout Storage  \
# 0  03/01/2005 04:00:00 PM +0000             835.10          46757.0
# 1  03/02/2005 04:00:00 PM +0000             834.98          46678.0
# 2  03/03/2005 04:00:00 PM +0000             834.84          46585.0
# 3  03/04/2005 04:00:00 PM +0000             834.85          46592.0
# 4  03/05/2005 04:00:00 PM +0000             834.88          46612.0
#
#     Schoharie Date               Schoharie Elevation  Schoharie Storage  \
# ...

# %%
data2 = data[['Neversink Elevation','Rondout Storage']]
data2
# Out:
#       Neversink Elevation  Rondout Storage
# 0                 1440.21          46757.0
# 1                 1440.22          46678.0
# 2                 1440.21          46585.0
# 3                 1440.21          46592.0
# 4                 1440.21          46612.0
# 5                 1440.21          46671.0
# 6                 1440.21          46737.0
# 7                 1440.24          46810.0
# 8                 1440.22          46843.0
# 9                 1440.22          46889.0
# 10                1440.22          47095.0
# 11                1440.22          47353.0
# 12                1440.21          47640.0
# 13                1440.20          47294.0
# 14                1440.20          47241.0
# 15                1440.18          47194.0
# 16                1440.18          47267.0
# 17                1440.18          47340.0
# 18                1440.18          47420.0
# 19                1440.18          47513.0
# 20                1440.15          47706.0
# ...

# %%
data2.columns = ["Neversink","Rondout"]
plt.scatter(data2.Neversink, data2.Rondout)
plt.xlabel("Neversink Elevation"); plt.ylabel("Rondout Storage")
plt.title("Water Resevoir Levels_Part Info")
